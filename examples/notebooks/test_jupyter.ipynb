# %%
# Cell 1: Verify Python Environment
import os
import sys

print(f'Python version: {sys.version}')
print(f'Python executable: {sys.executable}')
print('Expected path: /opt/conda/envs/gds/bin/python')
print('CONDA_DEFAULT_ENV:', os.environ.get('CONDA_DEFAULT_ENV'))
# Out:
# Python version: 3.14.2 | packaged by conda-forge | (main, Dec  6 2025, 11:21:58) [GCC 14.3.0]
# Python executable: /opt/conda/envs/gds/bin/python
# Expected path: /opt/conda/envs/gds/bin/python
# CONDA_DEFAULT_ENV: gds

# %%
# Cell 2: Verify Jupyter Packages
import ipykernel
import jupyterlab

print(f'ipykernel: {ipykernel.__version__}')
print(f'jupyterlab: {jupyterlab.__version__}')
# Out:
# ipykernel: 7.1.0
# jupyterlab: 4.5.1

# %%
# Cell 3: Test Basic Operations
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [10, 20, 30, 40]})
print("DataFrame created successfully:")
print(df)
print("\nSum of column A:", df["A"].sum())
# Out:
# DataFrame created successfully:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
#
# Sum of column A: 10

# %%
# Cell 4: Verify Environment Packages
try:
    import gds_database
    print("\u2713 gds_database available")
except ImportError:
    print("\u26a0 gds_database not installed (this is OK if not needed)")

import pkg_resources

packages = [d.project_name for d in pkg_resources.working_set]
print("\nTotal packages installed:", len(packages))
print("Sample packages:", ", ".join(sorted(packages)[:10]))
# Out:
# ✓ gds_database available
#
# Total packages installed: 194
# Sample packages: PyJWT, Send2Trash, aiohappyeyeballs, aiohttp, aiosignal, aiosmtplib, annotated-doc, annotated-types, anyio, argon2-cffi
# /tmp/ipykernel_7996/2883292724.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
