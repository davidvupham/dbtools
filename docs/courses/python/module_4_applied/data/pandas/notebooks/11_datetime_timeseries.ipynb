# %% [markdown]
# # 11 — Datetime + time series
#
# Mirrors: `chapters/11_datetime_timeseries.md`

# %%
import numpy as np
import pandas as pd


from pathlib import Path
import sys


# If running from the repository root, this makes the shared module importable:
shared = Path.cwd() / "docs" / "tutorials" / "python" / "modules" / "pandas" / "shared"
sys.path.insert(0, str(shared))

from make_orders import make_orders

orders = make_orders()
orders["order_date"] = pd.to_datetime(orders["order_date"], errors="coerce")
ts = orders.set_index("order_date").sort_index()
ts.head()

# %%
monthly_rev = ts["revenue"].resample("MS").sum()
monthly_rev.tail()

# %%
ts["rev_ma_7d"] = ts["revenue"].rolling("7D").mean()
ts[["revenue","rev_ma_7d"]].head(10)

# %%
ts["rev_lag_1"] = ts["revenue"].shift(1)
ts[["revenue","rev_lag_1"]].head(5)

# %%
idx = ts.index

ts = ts.assign(
    dow=idx.dayofweek,
    month=idx.month,
    week=idx.isocalendar().week.astype("int64"),
)

ts[["dow","month","week"]].head()
